# %% [markdown]
# <a href="https://colab.research.google.com/github/win71/python_1week/blob/master/%EC%B0%B8%EA%B3%A0_naver_music_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 참고: naver music

# %%
import urllib
import requests
from bs4 import BeautifulSoup as bs
import re

# %%
#url = "http://music.naver.com/lyric/index.nhn?trackId=17740104"
url = "http://music.naver.com/lyric/index.nhn?trackId=26074558"

r = requests.get(url)

bs_rt = bs(r.text, "html.parser")
print(bs_rt)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <title>네이버 뮤직</title>
# <link href="/css/music.css?bv=20190723155943" rel="stylesheet" type="text/css"/>
# <link href="/css/music2.css?bv=20190723155943" rel="stylesheet" type="text/css"/>
# <link href="/css/popup.css?bv=20190723155943" rel="stylesheet" type="text/css"/>
# <script charset="utf-8" src="/js/pkg_jindo.all.js?bv=20190723155943" type="text/javascript"></script>
# <script charset="utf-8" src="/js/pkg_external.all.js?bv=20190723155943" type="text/javascript"></script>
# <script charset="utf-8" src="/js/pkg_music.all.js?bv=20190723155943" type="text/javascript"></script>
# ...

# %%
lyric = bs_rt.find("div", id="lyricText")
text  = re.sub(r"<.*?>", "\\n", str(lyric))

print(text)

singer_list = text.split()
print(singer_list)
# Out:
# 나의 여자친구가 되어주겠니
# 이런 내 마음을 넌 받아주겠니
#
# 넌 누구보다 예뻐 넌 뭘 해도 다 예뻐
# 세상 하나뿐인 넌 정말 예뻐
#
# 꿈꿔온 여자친구 너 My love is only you
# 기다린 여자친구 너 My love is only you
# 지금 고백할까 말까 이런 내 맘 알까
# 점점 더 빠져드는 날 어떻게 해 Love is only you
# 꿈꿔온 내 사랑은 너 It's only you
#
# 내가 너의 맘에 들진 모르지만
# 이런 나의 진심을 알아주겠니
#
# 화장 안 해도 예뻐 넌 뭘 입어도 예뻐
# 세상 그 누구보다 넌 정말 예뻐
#
# 꿈꿔온 여자친구 너 My love is only you
# 기다린 여자친구 너 My love is only you
# 지금 고백할까 말까 이런 내 맘 알까
# 점점 더 빠져드는 날 어떻게 해
#
# 알고 있니 지금 내가 하고 싶은 말
# 더 예뻐지는 너 너만 보는 나 잘 어울려 우린
# 점점 더 빠져드는 점점 더 커져가는 Love
#
# My love is only you
# 내 눈을 보고 있는 너 말해야 할 것 같아
#
# 지금 사랑한다 할까 같은 마음일까
# 미칠 것만 같아 이런 내 맘 알까
# 이젠 나 고백할게 My love is only you It's only you
# 꿈꿔온 여자친구 너 It's only you
#
#
#
# ...

# %%
singer_set = set(singer_list)
singer_set
# Out:
# {"It's",
#  'Love',
#  'My',
#  'is',
#  'love',
#  'only',
#  'you',
#  '같아',
#  '같은',
#  '것',
#  '것만',
#  '고백할게',
#  '고백할까',
#  '그',
#  '기다린',
#  '꿈꿔온',
#  '나',
#  '나의',
#  '날',
#  '내',
#  '내가',
#  '너',
#  '너만',
#  '너의',
#  '넌',
#  '누구보다',
#  '눈을',
#  '다',
#  '더',
#  '되어주겠니',
#  '들진',
#  '마음을',
#  '마음일까',
#  '말',
#  '말까',
#  '말해야',
#  '맘',
#  '맘에',
#  '모르지만',
#  '뭘',
#  '미칠',
#  '받아주겠니',
#  '보고',
#  '보는',
#  '빠져드는',
#  '사랑은',
#  '사랑한다',
#  '세상',
#  '싶은',
#  '안',
#  '알고',
#  '알까',
#  '알아주겠니',
#  '어떻게',
#  '어울려',
#  '여자친구',
#  '여자친구가',
#  '예뻐',
#  '예뻐지는',
#  '우린',
#  '이런',
#  '이젠',
#  '입어도',
#  '있는',
#  '있니',
#  '잘',
#  '점점',
#  '정말',
#  '지금',
#  '진심을',
#  '커져가는',
#  '하고',
#  '하나뿐인',
#  '할',
#  '할까',
#  '해',
#  '해도',
#  '화장'}

# %%
import pandas as pd

# %%
url2 = "https://music.naver.com/listen/top100.nhn?domain=DOMESTIC_V2"

r2 = requests.get(url2)

naver_music = bs(r2.text, "html.parser")
print(naver_music)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <title>TOP 100 국내 : 네이버 뮤직</title>
# <link href="/css/music.css?bv=20190723155943" rel="stylesheet" type="text/css"/>
# <link href="/css/music2.css?bv=20190723155943" rel="stylesheet" type="text/css"/>
# <script charset="utf-8" src="/js/pkg_jindo.all.js?bv=20190723155943" type="text/javascript"></script>
# <script charset="utf-8" src="/js/pkg_external.all.js?bv=20190723155943" type="text/javascript"></script>
# ...

# %%
result = naver_music.find_all("a", title="가사")
print(result)
# Out:
# [<a class="_lyric lyric NPI=a:lyric,r:1,i:27346766" href="#" title="가사"><span>가사</span></a>, <a class="_lyric lyric NPI=a:lyric,r:2,i:27424533" href="#" title="가사"><span>가사</span></a>, <a class="_lyric lyric NPI=a:lyric,r:3,i:27357178" href="#" title="가사"><span>가사</span></a>, <a class="_lyric lyric NPI=a:lyric,r:4,i:21830789" href="#" title="가사"><span>가사</span></a>, <a class="_lyric lyric NPI=a:lyric,r:5,i:27259884" href="#" title="가사"><span>가사</span></a>, <a class="_lyric lyric NPI=a:lyric,r:6,i:26860934" href="#" title="가사"><span>가사</span></a>, <a class="_lyric lyric NPI=a:lyric,r:7,i:27324492" href="#" title="가사"><span>가사</span></a>, <a class="_lyric lyric NPI=a:lyric,r:8,i:27229835" href="#" title="가사"><span>가사</span></a>, <a class="_lyric lyric NPI=a:lyric,r:9,i:27395077" href="#" title="가사"><span>가사</span></a>, <a class="_lyric lyric NPI=a:lyric,r:10,i:27959118" href="#" title="가사"><span>가사</span></a>, <a class="_lyric lyric NPI=a:lyric,r:11,i:27061012" href="#" title="가사"><spa
# ...

# %%
title  = naver_music.find_all("span", class_="ellipsis")
print(title)
# Out:
# [<span class="ellipsis">술이 문제야</span>, <span class="ellipsis">헤어져줘서 고마워</span>, <span class="ellipsis">
#
#
# 			벤
# 		</span>, <span class="ellipsis">Snapping</span>, <span class="ellipsis">
#
#
# 			청하
# 		</span>, <span class="ellipsis">사랑에 연습이 있었다면 (Prod. 2soo)</span>, <span class="ellipsis">
#
#
# 			임재현
# 		</span>, <span class="ellipsis">너에게 못했던 내 마지막 말은</span>, <span class="ellipsis">
#
#
# 			다비치
# 		</span>, <span class="ellipsis">작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)</span>, <span class="ellipsis">솔직하게 말해서 나</span>, <span class="ellipsis">
#
#
# 			김나영
# 		</span>, <span class="ellipsis">니 소식</span>, <span class="ellipsis">
#
#
# 			송하예
# 		</span>, <span class="ellipsis">비가 내리는 날에는</span>, <span class="ellipsis">
#
#
# 			윤하
# 		</span>, <span class="ellipsis">그대라는 시</span>, <span class="ellipsis">
#
#
# 			태연 (TAEYEON)
# 		</span>, <span class="ellipsis">FANCY</span>, <span class="ellipsis">
#
#
# 			TWICE(트와이스)
# ...

# %%
title = naver_music.find_all("a", class_=re.compile("^_title"))
print(title)
# Out:
# [<a class="_title title NPI=a:track,r:1,i:27346766" href="#27346766" title="술이 문제야"><span class="ellipsis">술이 문제야</span></a>, <a class="_title title NPI=a:track,r:2,i:27424533" href="#27424533" title="헤어져줘서 고마워"><span class="ellipsis">헤어져줘서 고마워</span></a>, <a class="_title title NPI=a:track,r:3,i:27357178" href="#27357178" title="Snapping"><span class="ellipsis">Snapping</span></a>, <a class="_title title NPI=a:track,r:4,i:21830789" href="#21830789" title="사랑에 연습이 있었다면 (Prod. 2soo)"><span class="ellipsis">사랑에 연습이 있었다면 (Prod. 2soo)</span></a>, <a class="_title title NPI=a:track,r:5,i:27259884" href="#27259884" title="너에게 못했던 내 마지막 말은"><span class="ellipsis">너에게 못했던 내 마지막 말은</span></a>, <a class="_title title NPI=a:track,r:6,i:26860934" href="#26860934" title="작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)"><span class="ellipsis">작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)</span></a>, <a class="_title title NPI=a:track,r:7,i:27324492" href="#27324492" title="솔직하게 말해서 나"><span class="ellipsis"
# ...

# %%
singer = naver_music.find_all("td", class_=re.compile("^_artist artist"))
print(title)
# Out:
# [<a class="_title title NPI=a:track,r:1,i:27346766" href="#27346766" title="술이 문제야"><span class="ellipsis">술이 문제야</span></a>, <a class="_title title NPI=a:track,r:2,i:27424533" href="#27424533" title="헤어져줘서 고마워"><span class="ellipsis">헤어져줘서 고마워</span></a>, <a class="_title title NPI=a:track,r:3,i:27357178" href="#27357178" title="Snapping"><span class="ellipsis">Snapping</span></a>, <a class="_title title NPI=a:track,r:4,i:21830789" href="#21830789" title="사랑에 연습이 있었다면 (Prod. 2soo)"><span class="ellipsis">사랑에 연습이 있었다면 (Prod. 2soo)</span></a>, <a class="_title title NPI=a:track,r:5,i:27259884" href="#27259884" title="너에게 못했던 내 마지막 말은"><span class="ellipsis">너에게 못했던 내 마지막 말은</span></a>, <a class="_title title NPI=a:track,r:6,i:26860934" href="#26860934" title="작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)"><span class="ellipsis">작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)</span></a>, <a class="_title title NPI=a:track,r:7,i:27324492" href="#27324492" title="솔직하게 말해서 나"><span class="ellipsis"
# ...

# %%
singer_list = []

for idx, xx in enumerate(singer):
    if(idx == 0): continue
    
    print (idx, xx.text.strip())
    singer_list.append(xx.text.strip())
# Out:
# 1 장혜진
# 2 벤
# 3 청하
# 4 임재현
# 5 다비치
# 6 방탄소년단
# 7 김나영
# 8 송하예
# 9 윤하
# 10 태연 (TAEYEON)
# 11 TWICE(트와이스)
# 12 황인욱
# 13 태연 (TAEYEON)
# 14 여자친구(GFRIEND)
# 15 멜로망스(Melomance)
# 16 헤이즈 (Heize)
# 17 박효신
# 18 폴킴
# 19 청하
# 20 Red Velvet (레드벨벳)
# 21 마크툽(Maktub)
# 22 잔나비
# 23 전소미
# 24 ITZY(있지)
# 25 케이시(Kassy)
# 26 폴킴
# 27 BLACKPINK
# 28 장범준
# 29 볼빨간사춘기
# 30 IZ*ONE(아이즈원)
# 31 엔플라잉(N.Flying)
# 32 TWICE(트와이스)
# 33 먼데이키즈(Monday Kiz)
# 34 갓츄 (GOT U)
# 35 10cm
# 36 M.C THE MAX
# 37 이하이
# 38 볼빨간사춘기
# 39 이소라
# 40 먼데이키즈(Mon..
# 41 아이유(IU)
# 42 어반 자카파(Urban Zakapa)
# 43 강다니엘
# 44 창모(CHANGM..
# 45 기리보이
# 46 (여자) 아이들
# 47 숀(SHAUN)
# 48 방탄소년단
# 49 SIXC (6 crazy)
# 50 양다일

# %%
title_list = []

for idx, xx in enumerate(title):
    print (idx + 1, xx.text.strip())
    title_list.append(xx.text.strip())
# Out:
# 1 술이 문제야
# 2 헤어져줘서 고마워
# 3 Snapping
# 4 사랑에 연습이 있었다면 (Prod. 2soo)
# 5 너에게 못했던 내 마지막 말은
# 6 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 7 솔직하게 말해서 나
# 8 니 소식
# 9 비가 내리는 날에는
# 10 그대라는 시
# 11 FANCY
# 12 포장마차
# 13 사계 (Four Seasons)
# 14 열대야 (Fever)
# 15 인사
# 16 We don't talk together (Feat. 기리보이) (Prod. SUGA)
# 17 Goodbye
# 18 너를 만나
# 19 벌써 12시
# 20 짐살라빔 (Zimzalabim)
# 21 오늘도 빛나는 너에게 (To You My Light) (Feat. 이라온)
# 22 주저하는 연인들을 위해
# 23 BIRTHDAY
# 24 달라달라
# 25 그때가 좋았어
# 26 모든 날, 모든 순간 (Every day, Every Moment)
# 27 Kill This Love
# 28 노래방에서
# 29 나만, 봄
# 30 비올레타
# 31 옥탑방 (Rooftop)
# 32 Dance The Night Away
# 33 사랑이 식었다고 말해도 돼
# 34 U GOT IT
# 35 나의 어깨에 기대어요
# 36 넘쳐흘러
# 37 누구 없소 (NO ONE) (Feat. B.I of iKON)
# 38 여행
# 39 신청곡 (Feat. SUGA of BTS)
# 40 Another Day
# 41 밤편지
# 42 서울 밤 (Feat. 빈지노)
# 43 뭐해 (What are you up to)
# 44 BAND
# 45 아퍼 (Feat. Kid Milli, Lil tachi, 김승민, NO:EL, C JAMM)
# 46 Uh-Oh
# 47 Way Back Home
# 48 소우주 (Mikrokosmos)
# 49 움직여 (MOVE) (Prod. by ZICO)
# 50 고백

# %%
p = re.compile(r"[0-9]{4,10}")
all_music = p.findall(str(result))

# %%
all_music
# Out:
# ['27346766',
#  '27424533',
#  '27357178',
#  '21830789',
#  '27259884',
#  '26860934',
#  '27324492',
#  '27229835',
#  '27395077',
#  '27959118',
#  '27061012',
#  '27349781',
#  '26386030',
#  '27372467',
#  '27657146',
#  '27476966',
#  '27166185',
#  '22307355',
#  '25169012',
#  '27349409',
#  '27319711',
#  '26193354',
#  '27336761',
#  '25534507',
#  '25094091',
#  '21064399',
#  '26687892',
#  '26357263',
#  '26650926',
#  '26630822',
#  '25169425',
#  '21456798',
#  '27296186',
#  '27476930',
#  '27958964',
#  '25169374',
#  '27306725',
#  '21335966',
#  '25343793',
#  '27779683',
#  '16676937',
#  '27336979',
#  '27961988',
#  '27324507',
#  '27327936',
#  '27361344',
#  '21412948',
#  '26860936',
#  '27476932',
#  '22235936']

# %%
len(all_music)
# Out:
# 50

# %%
# 이 아래 소스는 네이버 뮤직에서 가사를 가져오는 소스이다. 
# 최신 인기가요 50곡의 가사를 출력한다. 
# 매일 매일 순위가 변경된다.


url_pre = "http://music.naver.com/lyric/index.nhn?trackId="

for idx, xxx in enumerate(all_music):
    url = "{}{}".format(url_pre, xxx)
    #print (url)
    r = requests.get(url)

    bs_rt = bs(r.text, "html.parser")
    lyric = bs_rt.find("div", id="lyricText")
    text = re.sub(r"<.*?>", "\\n", str(lyric))
    print (title_list[idx])
    print (text)
    try:
        f = open('data/' + '{:02d}_'.format(idx+1) + title_list[idx] + '.txt', 'w', encoding='utf-8')
        f.write(text)
        f.close()
    except:
        pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-3c4f6e16ad73> in <module>()
#       3 url_pre = "http://music.naver.com/lyric/index.nhn?trackId="
#       4
# ----> 5 for idx, xxx in enumerate(all_music):
#       6     url = "{}{}".format(url_pre, xxx)
#       7     #print (url)
#
# NameError: name 'all_music' is not defined

# %% [markdown]
# ---

# %%
# end of file
